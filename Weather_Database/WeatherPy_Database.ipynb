# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 741

# %%
# Import the requests library.
import requests

# Import the API key.
from config_Copy1 import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather Description": description,})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 1 | nampa
# Processing Record 3 of Set 1 | nizhnevartovsk
# Processing Record 4 of Set 1 | bahia blanca
# Processing Record 5 of Set 1 | punta arenas
# Processing Record 6 of Set 1 | manggar
# Processing Record 7 of Set 1 | guerrero negro
# Processing Record 8 of Set 1 | nanortalik
# Processing Record 9 of Set 1 | kapaa
# Processing Record 10 of Set 1 | mount isa
# Processing Record 11 of Set 1 | foligno
# Processing Record 12 of Set 1 | upernavik
# Processing Record 13 of Set 1 | barberton
# Processing Record 14 of Set 1 | santa marta
# Processing Record 15 of Set 1 | mogadishu
# Processing Record 16 of Set 1 | souillac
# Processing Record 17 of Set 1 | rikitea
# Processing Record 18 of Set 1 | chokurdakh
# Processing Record 19 of Set 1 | barrow
# Processing Record 20 of Set 1 | puerto ayora
# Processing Record 21 of Set 1 | khatanga
# Processing Record 22 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 23 of Set 1 | muzhi
# Processing Record 24 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 25 of Set 1 | yellowknife
# Processing Record 26 of Set 1 | flinders
# Processing Record 27 of Set 1 | vrable
# Processing Record 28 of Set 1 | cape town
# Processing Record 29 of Set 1 | maku
# Processing Record 30 of Set 1 | kimbe
# Processing Record 31 of Set 1 | albany
# Processing Record 32 of Set 1 | lorengau
# Processing Record 33 of Set 1 | shimanovsk
# Processing Record 34 of Set 1 | pascagoula
# Processing Record 35 of Set 1 | lazaro cardenas
# Processing Record 36 of Set 1 | busselton
# Processing Record 37 of Set 1 | lebu
# Processing Record 38 of Set 1 | jamestown
# Processing Record 39 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 40 of Set 1 | tortoli
# Processing Record 41 of Set 1 | kemin
# Processing Record 42 of Set 1 | lata
# Processing Record 43 of Set 1 | preobrazheniye
# Processing Record 44 of Set 1 | hobart
# Processing Record 45 of Set 1 | champoton
# Processing Record 46 of Set 1 | cabo san lucas
# Processing Record 47 of Set 1 | algiers
# Processing Record 48 of Set 1 | new norfolk
# Processing Record 49 of Set 1 | kirakira
# Processing Record 50 of Set 1 | kalakamati
# Processing Record 1 of Set 2 | esperance
# Processing Record 2 of Set 2 | hilo
# Processing Record 3 of Set 2 | harper
# Processing Record 4 of Set 2 | hualmay
# Processing Record 5 of Set 2 | qaanaaq
# Processing Record 6 of Set 2 | fortuna
# Processing Record 7 of Set 2 | seinajoki
# Processing Record 8 of Set 2 | san carlos
# Processing Record 9 of Set 2 | tuktoyaktuk
# Processing Record 10 of Set 2 | port augusta
# Processing Record 11 of Set 2 | winchester
# Processing Record 12 of Set 2 | aklavik
# Processing Record 13 of Set 2 | joshimath
# Processing Record 14 of Set 2 | urdoma
# Processing Record 15 of Set 2 | ushuaia
# Processing Record 16 of Set 2 | tres picos
# Processing Record 17 of Set 2 | avarua
# Processing Record 18 of Set 2 | hithadhoo
# Processing Record 19 of Set 2 | mataura
# Processing Record 20 of Set 2 | victoria
# Processing Record 21 of Set 2 | qaqortoq
# Processing Record 22 of Set 2 | arraial do cabo
# Processing Record 23 of Set 2 | svetlaya
# Processing Record 24 of Set 2 | dikson
# Processing Record 25 of Set 2 | anchorage
# Processing Record 26 of Set 2 | atuona
# Processing Record 27 of Set 2 | santarem
# Processing Record 28 of Set 2 | shelburne
# Processing Record 29 of Set 2 | wabash
# Processing Record 30 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 31 of Set 2 | avera
# Processing Record 32 of Set 2 | jieshi
# Processing Record 33 of Set 2 | castro
# Processing Record 34 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 35 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 36 of Set 2 | sitka
# Processing Record 37 of Set 2 | saskylakh
# Processing Record 38 of Set 2 | vestmanna
# Processing Record 39 of Set 2 | kasongo-lunda
# Processing Record 40 of Set 2 | abbeville
# Processing Record 41 of Set 2 | juruti
# Processing Record 42 of Set 2 | hermanus
# Processing Record 43 of Set 2 | vaini
# Processing Record 44 of Set 2 | marsh harbour
# Processing Record 45 of Set 2 | jiddah
# City not found. Skipping...
# Processing Record 46 of Set 2 | taoudenni
# Processing Record 47 of Set 2 | zhigansk
# Processing Record 48 of Set 2 | saint george
# Processing Record 49 of Set 2 | hamilton
# Processing Record 50 of Set 2 | iralaya
# Processing Record 1 of Set 3 | luderitz
# Processing Record 2 of Set 3 | pevek
# Processing Record 3 of Set 3 | airai
# Processing Record 4 of Set 3 | otjiwarongo
# Processing Record 5 of Set 3 | bainbridge
# Processing Record 6 of Set 3 | gorontalo
# Processing Record 7 of Set 3 | riyadh
# Processing Record 8 of Set 3 | chapais
# Processing Record 9 of Set 3 | palani
# Processing Record 10 of Set 3 | constitucion
# Processing Record 11 of Set 3 | goure
# Processing Record 12 of Set 3 | ust-omchug
# Processing Record 13 of Set 3 | yirol
# City not found. Skipping...
# Processing Record 14 of Set 3 | huangnihe
# Processing Record 15 of Set 3 | adolfo lopez mateos
# Processing Record 16 of Set 3 | srednekolymsk
# Processing Record 17 of Set 3 | naze
# Processing Record 18 of Set 3 | san carlos de bariloche
# Processing Record 19 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 3 | andra
# Processing Record 21 of Set 3 | bethel
# Processing Record 22 of Set 3 | bredasdorp
# Processing Record 23 of Set 3 | roma
# Processing Record 24 of Set 3 | sao joao da barra
# Processing Record 25 of Set 3 | ilulissat
# Processing Record 26 of Set 3 | hofn
# Processing Record 27 of Set 3 | sistranda
# Processing Record 28 of Set 3 | karpathos
# Processing Record 29 of Set 3 | auki
# Processing Record 30 of Set 3 | jalu
# Processing Record 31 of Set 3 | komsomolskiy
# Processing Record 32 of Set 3 | asfi
# Processing Record 33 of Set 3 | fukue
# Processing Record 34 of Set 3 | lavrentiya
# Processing Record 35 of Set 3 | sioux lookout
# Processing Record 36 of Set 3 | kapit
# Processing Record 37 of Set 3 | ulaangom
# Processing Record 38 of Set 3 | mahebourg
# Processing Record 39 of Set 3 | ruatoria
# City not found. Skipping...
# Processing Record 40 of Set 3 | kidal
# Processing Record 41 of Set 3 | baneh
# Processing Record 42 of Set 3 | buin
# Processing Record 43 of Set 3 | geraldton
# Processing Record 44 of Set 3 | leninskoye
# Processing Record 45 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 46 of Set 3 | saint-philippe
# Processing Record 47 of Set 3 | pacific grove
# Processing Record 48 of Set 3 | deh rawud
# City not found. Skipping...
# Processing Record 49 of Set 3 | hambantota
# Processing Record 50 of Set 3 | niteroi
# Processing Record 1 of Set 4 | antofagasta
# Processing Record 2 of Set 4 | bluff
# Processing Record 3 of Set 4 | san cristobal
# Processing Record 4 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 5 of Set 4 | turukhansk
# Processing Record 6 of Set 4 | songadh
# Processing Record 7 of Set 4 | elko
# Processing Record 8 of Set 4 | port alfred
# Processing Record 9 of Set 4 | clyde river
# Processing Record 10 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 11 of Set 4 | kuching
# Processing Record 12 of Set 4 | tecoanapa
# Processing Record 13 of Set 4 | hay river
# Processing Record 14 of Set 4 | sfantu gheorghe
# Processing Record 15 of Set 4 | bestobe
# Processing Record 16 of Set 4 | namatanai
# Processing Record 17 of Set 4 | januaria
# Processing Record 18 of Set 4 | sayyan
# Processing Record 19 of Set 4 | te anau
# Processing Record 20 of Set 4 | atkarsk
# Processing Record 21 of Set 4 | mar del plata
# Processing Record 22 of Set 4 | virginia beach
# Processing Record 23 of Set 4 | arenapolis
# Processing Record 24 of Set 4 | puerto narino
# Processing Record 25 of Set 4 | cherskiy
# Processing Record 26 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 27 of Set 4 | ponta do sol
# Processing Record 28 of Set 4 | yerbogachen
# Processing Record 29 of Set 4 | basco
# Processing Record 30 of Set 4 | sokolow podlaski
# Processing Record 31 of Set 4 | spencer
# Processing Record 32 of Set 4 | mehamn
# Processing Record 33 of Set 4 | alofi
# Processing Record 34 of Set 4 | kamra
# Processing Record 35 of Set 4 | kahului
# Processing Record 36 of Set 4 | nhamunda
# Processing Record 37 of Set 4 | thompson
# Processing Record 38 of Set 4 | touros
# Processing Record 39 of Set 4 | leshukonskoye
# Processing Record 40 of Set 4 | yingcheng
# Processing Record 41 of Set 4 | williston
# Processing Record 42 of Set 4 | churapcha
# Processing Record 43 of Set 4 | utinga
# Processing Record 44 of Set 4 | longkou
# Processing Record 45 of Set 4 | iqaluit
# Processing Record 46 of Set 4 | lasa
# Processing Record 47 of Set 4 | toumodi
# Processing Record 48 of Set 4 | ribeira grande
# Processing Record 49 of Set 4 | pisco
# Processing Record 50 of Set 4 | lakes entrance
# Processing Record 1 of Set 5 | nikolskoye
# Processing Record 2 of Set 5 | amursk
# Processing Record 3 of Set 5 | codrington
# Processing Record 4 of Set 5 | honiara
# Processing Record 5 of Set 5 | lethem
# Processing Record 6 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 7 of Set 5 | troitsko-pechorsk
# Processing Record 8 of Set 5 | nome
# Processing Record 9 of Set 5 | elizabeth city
# Processing Record 10 of Set 5 | tapaua
# City not found. Skipping...
# Processing Record 11 of Set 5 | necochea
# Processing Record 12 of Set 5 | puerto colombia
# Processing Record 13 of Set 5 | cazaje
# City not found. Skipping...
# Processing Record 14 of Set 5 | port elizabeth
# Processing Record 15 of Set 5 | klaksvik
# Processing Record 16 of Set 5 | caravelas
# Processing Record 17 of Set 5 | burica
# City not found. Skipping...
# Processing Record 18 of Set 5 | college
# Processing Record 19 of Set 5 | rudnya
# Processing Record 20 of Set 5 | sao filipe
# Processing Record 21 of Set 5 | derzhavinsk
# Processing Record 22 of Set 5 | temaraia
# City not found. Skipping...
# Processing Record 23 of Set 5 | havelock
# Processing Record 24 of Set 5 | oksfjord
# Processing Record 25 of Set 5 | faanui
# Processing Record 26 of Set 5 | mansa
# Processing Record 27 of Set 5 | yamada
# Processing Record 28 of Set 5 | sobolevo
# Processing Record 29 of Set 5 | vardo
# Processing Record 30 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 31 of Set 5 | labuhan
# Processing Record 32 of Set 5 | ha giang
# Processing Record 33 of Set 5 | singaparna
# Processing Record 34 of Set 5 | waingapu
# Processing Record 35 of Set 5 | pinega
# Processing Record 36 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 37 of Set 5 | hojai
# Processing Record 38 of Set 5 | krasnoselkup
# Processing Record 39 of Set 5 | cidreira
# Processing Record 40 of Set 5 | kishi
# Processing Record 41 of Set 5 | broome
# Processing Record 42 of Set 5 | ola
# Processing Record 43 of Set 5 | sungaipenuh
# Processing Record 44 of Set 5 | chitral
# Processing Record 45 of Set 5 | perry
# Processing Record 46 of Set 5 | dingle
# Processing Record 47 of Set 5 | provins
# Processing Record 48 of Set 5 | saryozek
# Processing Record 49 of Set 5 | aleksandrov gay
# Processing Record 50 of Set 5 | smiths falls
# Processing Record 1 of Set 6 | kaitangata
# Processing Record 2 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 3 of Set 6 | simiti
# Processing Record 4 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 5 of Set 6 | noumea
# Processing Record 6 of Set 6 | namibe
# Processing Record 7 of Set 6 | bafia
# Processing Record 8 of Set 6 | tasiilaq
# Processing Record 9 of Set 6 | leningradskiy
# Processing Record 10 of Set 6 | bambous virieux
# Processing Record 11 of Set 6 | tacuarembo
# Processing Record 12 of Set 6 | tual
# Processing Record 13 of Set 6 | qasigiannguit
# Processing Record 14 of Set 6 | tsumeb
# Processing Record 15 of Set 6 | veraval
# Processing Record 16 of Set 6 | thinadhoo
# Processing Record 17 of Set 6 | port lincoln
# Processing Record 18 of Set 6 | karamea
# City not found. Skipping...
# Processing Record 19 of Set 6 | ust-ishim
# Processing Record 20 of Set 6 | la paz
# Processing Record 21 of Set 6 | arzgir
# Processing Record 22 of Set 6 | aden
# Processing Record 23 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 24 of Set 6 | labutta
# City not found. Skipping...
# Processing Record 25 of Set 6 | mankono
# Processing Record 26 of Set 6 | tome-acu
# City not found. Skipping...
# Processing Record 27 of Set 6 | grootfontein
# Processing Record 28 of Set 6 | bathsheba
# Processing Record 29 of Set 6 | illapel
# Processing Record 30 of Set 6 | bam
# Processing Record 31 of Set 6 | abay
# Processing Record 32 of Set 6 | anadyr
# Processing Record 33 of Set 6 | quetame
# Processing Record 34 of Set 6 | aktau
# Processing Record 35 of Set 6 | ambilobe
# Processing Record 36 of Set 6 | harqalah
# Processing Record 37 of Set 6 | vermilion
# Processing Record 38 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 39 of Set 6 | gangotri
# City not found. Skipping...
# Processing Record 40 of Set 6 | bundi
# Processing Record 41 of Set 6 | aron
# Processing Record 42 of Set 6 | brae
# Processing Record 43 of Set 6 | butaritari
# Processing Record 44 of Set 6 | richards bay
# Processing Record 45 of Set 6 | morristown
# Processing Record 46 of Set 6 | zarautz
# Processing Record 47 of Set 6 | bonthe
# Processing Record 48 of Set 6 | ponta delgada
# Processing Record 49 of Set 6 | mayya
# Processing Record 50 of Set 6 | coquimbo
# Processing Record 1 of Set 7 | ocumare del tuy
# Processing Record 2 of Set 7 | nouadhibou
# Processing Record 3 of Set 7 | tiksi
# Processing Record 4 of Set 7 | ishigaki
# Processing Record 5 of Set 7 | xichang
# Processing Record 6 of Set 7 | vao
# Processing Record 7 of Set 7 | kutum
# Processing Record 8 of Set 7 | taman
# Processing Record 9 of Set 7 | kalmunai
# Processing Record 10 of Set 7 | ahipara
# Processing Record 11 of Set 7 | pitimbu
# Processing Record 12 of Set 7 | ruteng
# Processing Record 13 of Set 7 | dudinka
# Processing Record 14 of Set 7 | georgetown
# Processing Record 15 of Set 7 | coahuayana
# Processing Record 16 of Set 7 | beringovskiy
# Processing Record 17 of Set 7 | ust-uda
# Processing Record 18 of Set 7 | kruisfontein
# Processing Record 19 of Set 7 | ust-maya
# Processing Record 20 of Set 7 | gat
# Processing Record 21 of Set 7 | thunder bay
# Processing Record 22 of Set 7 | loubomo
# Processing Record 23 of Set 7 | kanigiri
# Processing Record 24 of Set 7 | hatta
# Processing Record 25 of Set 7 | tabuk
# Processing Record 26 of Set 7 | sarankhola
# Processing Record 27 of Set 7 | belmonte
# Processing Record 28 of Set 7 | orapa
# Processing Record 29 of Set 7 | buluang
# Processing Record 30 of Set 7 | quang ngai
# Processing Record 31 of Set 7 | nodeland
# Processing Record 32 of Set 7 | phan rang
# City not found. Skipping...
# Processing Record 33 of Set 7 | saint-ambroise
# Processing Record 34 of Set 7 | ancud
# Processing Record 35 of Set 7 | mirabad
# Processing Record 36 of Set 7 | bubaque
# Processing Record 37 of Set 7 | san vicente
# Processing Record 38 of Set 7 | peleduy
# Processing Record 39 of Set 7 | kemijarvi
# Processing Record 40 of Set 7 | norrtalje
# Processing Record 41 of Set 7 | luganville
# Processing Record 42 of Set 7 | isangel
# Processing Record 43 of Set 7 | mareeba
# Processing Record 44 of Set 7 | saldanha
# Processing Record 45 of Set 7 | seymchan
# Processing Record 46 of Set 7 | aybak
# City not found. Skipping...
# Processing Record 47 of Set 7 | catamarca
# Processing Record 48 of Set 7 | san rafael
# Processing Record 49 of Set 7 | santa luzia
# Processing Record 50 of Set 7 | rawson
# Processing Record 1 of Set 8 | east london
# Processing Record 2 of Set 8 | ostrovnoy
# Processing Record 3 of Set 8 | smithers
# Processing Record 4 of Set 8 | phek
# Processing Record 5 of Set 8 | tabukiniberu
# City not found. Skipping...
# Processing Record 6 of Set 8 | coihueco
# Processing Record 7 of Set 8 | hue
# Processing Record 8 of Set 8 | uyuni
# Processing Record 9 of Set 8 | san patricio
# Processing Record 10 of Set 8 | havre-saint-pierre
# Processing Record 11 of Set 8 | cikampek
# Processing Record 12 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 13 of Set 8 | hvide sande
# Processing Record 14 of Set 8 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 15 of Set 8 | wagar
# Processing Record 16 of Set 8 | hobyo
# Processing Record 17 of Set 8 | arlit
# Processing Record 18 of Set 8 | sinnamary
# Processing Record 19 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 20 of Set 8 | orlik
# Processing Record 21 of Set 8 | chuy
# Processing Record 22 of Set 8 | tuatapere
# Processing Record 23 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 24 of Set 8 | vila franca do campo
# Processing Record 25 of Set 8 | suicheng
# Processing Record 26 of Set 8 | los llanos de aridane
# Processing Record 27 of Set 8 | jining
# Processing Record 28 of Set 8 | carnarvon
# Processing Record 29 of Set 8 | tsabong
# Processing Record 30 of Set 8 | beruni
# City not found. Skipping...
# Processing Record 31 of Set 8 | roald
# Processing Record 32 of Set 8 | road town
# Processing Record 33 of Set 8 | aksarka
# Processing Record 34 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 35 of Set 8 | narsaq
# Processing Record 36 of Set 8 | coihaique
# Processing Record 37 of Set 8 | makakilo city
# Processing Record 38 of Set 8 | grants pass
# Processing Record 39 of Set 8 | maldonado
# Processing Record 40 of Set 8 | langxiang
# Processing Record 41 of Set 8 | nanzhang
# Processing Record 42 of Set 8 | forest acres
# Processing Record 43 of Set 8 | margate
# Processing Record 44 of Set 8 | tommot
# Processing Record 45 of Set 8 | severo-kurilsk
# Processing Record 46 of Set 8 | manthani
# Processing Record 47 of Set 8 | teya
# Processing Record 48 of Set 8 | falealupo
# City not found. Skipping...
# Processing Record 49 of Set 8 | hasaki
# Processing Record 50 of Set 8 | medea
# Processing Record 1 of Set 9 | san bernardo
# Processing Record 2 of Set 9 | kavieng
# Processing Record 3 of Set 9 | kodiak
# Processing Record 4 of Set 9 | norman wells
# Processing Record 5 of Set 9 | nishihara
# Processing Record 6 of Set 9 | rapid valley
# Processing Record 7 of Set 9 | bengkulu
# Processing Record 8 of Set 9 | santiago del estero
# Processing Record 9 of Set 9 | kaoma
# Processing Record 10 of Set 9 | mandalgovi
# Processing Record 11 of Set 9 | zamosc
# Processing Record 12 of Set 9 | udachnyy
# Processing Record 13 of Set 9 | bundaberg
# Processing Record 14 of Set 9 | balkhash
# Processing Record 15 of Set 9 | longyearbyen
# Processing Record 16 of Set 9 | nioro
# Processing Record 17 of Set 9 | marystown
# Processing Record 18 of Set 9 | mount gambier
# Processing Record 19 of Set 9 | atar
# Processing Record 20 of Set 9 | la baule-escoublac
# Processing Record 21 of Set 9 | palembang
# Processing Record 22 of Set 9 | tanout
# Processing Record 23 of Set 9 | lerwick
# Processing Record 24 of Set 9 | dalian
# Processing Record 25 of Set 9 | rozivka
# Processing Record 26 of Set 9 | navolato
# Processing Record 27 of Set 9 | tiarei
# Processing Record 28 of Set 9 | torbay
# Processing Record 29 of Set 9 | yulara
# Processing Record 30 of Set 9 | angoram
# Processing Record 31 of Set 9 | tazovskiy
# Processing Record 32 of Set 9 | provideniya
# Processing Record 33 of Set 9 | abrau-dyurso
# Processing Record 34 of Set 9 | pietarsaari
# Processing Record 35 of Set 9 | meulaboh
# Processing Record 36 of Set 9 | beloha
# Processing Record 37 of Set 9 | aykhal
# Processing Record 38 of Set 9 | moron
# Processing Record 39 of Set 9 | jahrom
# City not found. Skipping...
# Processing Record 40 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 41 of Set 9 | koubia
# Processing Record 42 of Set 9 | cuamba
# Processing Record 43 of Set 9 | puerto del rosario
# Processing Record 44 of Set 9 | chicama
# Processing Record 45 of Set 9 | general roca
# Processing Record 46 of Set 9 | katsuura
# Processing Record 47 of Set 9 | andijon
# Processing Record 48 of Set 9 | salalah
# Processing Record 49 of Set 9 | maningrida
# Processing Record 50 of Set 9 | babu
# Processing Record 1 of Set 10 | sur
# Processing Record 2 of Set 10 | saint-georges
# Processing Record 3 of Set 10 | skjervoy
# Processing Record 4 of Set 10 | severnyy
# Processing Record 5 of Set 10 | sao bernardo
# Processing Record 6 of Set 10 | santa isabel do rio negro
# Processing Record 7 of Set 10 | alice springs
# Processing Record 8 of Set 10 | hami
# Processing Record 9 of Set 10 | iwata
# Processing Record 10 of Set 10 | iracoubo
# Processing Record 11 of Set 10 | cassilandia
# Processing Record 12 of Set 10 | pombas
# Processing Record 13 of Set 10 | voh
# Processing Record 14 of Set 10 | znamenskoye
# Processing Record 15 of Set 10 | kijang
# Processing Record 16 of Set 10 | port-gentil
# Processing Record 17 of Set 10 | kuytun
# Processing Record 18 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 19 of Set 10 | korla
# Processing Record 20 of Set 10 | union hidalgo
# Processing Record 21 of Set 10 | camara de lobos
# Processing Record 22 of Set 10 | klyuchi
# Processing Record 23 of Set 10 | kurilsk
# Processing Record 24 of Set 10 | kudahuvadhoo
# Processing Record 25 of Set 10 | chiredzi
# Processing Record 26 of Set 10 | ulaanbaatar
# Processing Record 27 of Set 10 | kavaratti
# Processing Record 28 of Set 10 | pangnirtung
# Processing Record 29 of Set 10 | san antonio
# Processing Record 30 of Set 10 | vila do maio
# Processing Record 31 of Set 10 | wanning
# Processing Record 32 of Set 10 | ust-karsk
# Processing Record 33 of Set 10 | paamiut
# Processing Record 34 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 35 of Set 10 | qui nhon
# Processing Record 36 of Set 10 | nicolas bravo
# Processing Record 37 of Set 10 | san pedro
# Processing Record 38 of Set 10 | melfi
# Processing Record 39 of Set 10 | lubao
# Processing Record 40 of Set 10 | kasiri
# Processing Record 41 of Set 10 | nelson bay
# Processing Record 42 of Set 10 | yar-sale
# Processing Record 43 of Set 10 | ahar
# Processing Record 44 of Set 10 | kungurtug
# Processing Record 45 of Set 10 | sonkovo
# Processing Record 46 of Set 10 | dover
# Processing Record 47 of Set 10 | lomza
# Processing Record 48 of Set 10 | nemuro
# Processing Record 49 of Set 10 | detva
# Processing Record 50 of Set 10 | carupano
# Processing Record 1 of Set 11 | zeya
# Processing Record 2 of Set 11 | puerto ayacucho
# Processing Record 3 of Set 11 | bilma
# Processing Record 4 of Set 11 | saint-pierre
# Processing Record 5 of Set 11 | husavik
# Processing Record 6 of Set 11 | lekoni
# Processing Record 7 of Set 11 | selfoss
# Processing Record 8 of Set 11 | abha
# Processing Record 9 of Set 11 | vagur
# Processing Record 10 of Set 11 | fort morgan
# Processing Record 11 of Set 11 | asau
# Processing Record 12 of Set 11 | yasenskaya
# Processing Record 13 of Set 11 | khash
# Processing Record 14 of Set 11 | shenjiamen
# Processing Record 15 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 16 of Set 11 | les escoumins
# Processing Record 17 of Set 11 | yuanli
# Processing Record 18 of Set 11 | eydhafushi
# Processing Record 19 of Set 11 | barranca
# Processing Record 20 of Set 11 | podgornoye
# Processing Record 21 of Set 11 | mayo
# Processing Record 22 of Set 11 | kenora
# Processing Record 23 of Set 11 | amapa
# Processing Record 24 of Set 11 | santa fe de la laguna
# Processing Record 25 of Set 11 | quthing
# Processing Record 26 of Set 11 | lar
# Processing Record 27 of Set 11 | morinville
# Processing Record 28 of Set 11 | la romana
# Processing Record 29 of Set 11 | makasar
# Processing Record 30 of Set 11 | huarmey
# Processing Record 31 of Set 11 | pombia
# Processing Record 32 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 33 of Set 11 | myatlevo
# Processing Record 34 of Set 11 | mizan teferi
# Processing Record 35 of Set 11 | mrirt
# City not found. Skipping...
# Processing Record 36 of Set 11 | batemans bay
# Processing Record 37 of Set 11 | sola
# Processing Record 38 of Set 11 | boyolangu
# Processing Record 39 of Set 11 | ustye
# Processing Record 40 of Set 11 | sidi ali
# Processing Record 41 of Set 11 | magnor
# Processing Record 42 of Set 11 | plouzane
# Processing Record 43 of Set 11 | solovetskiy
# City not found. Skipping...
# Processing Record 44 of Set 11 | kikwit
# Processing Record 45 of Set 11 | sesvete
# Processing Record 46 of Set 11 | henties bay
# Processing Record 47 of Set 11 | dunedin
# Processing Record 48 of Set 11 | ust-nera
# Processing Record 49 of Set 11 | balakhninskiy
# Processing Record 50 of Set 11 | cariamanga
# Processing Record 1 of Set 12 | saint anthony
# Processing Record 2 of Set 12 | chor
# Processing Record 3 of Set 12 | alotau
# City not found. Skipping...
# Processing Record 4 of Set 12 | ketchikan
# Processing Record 5 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 6 of Set 12 | aztec
# Processing Record 7 of Set 12 | stornoway
# Processing Record 8 of Set 12 | ahumada
# City not found. Skipping...
# Processing Record 9 of Set 12 | malinovoye ozero
# Processing Record 10 of Set 12 | egvekinot
# Processing Record 11 of Set 12 | kakonko
# Processing Record 12 of Set 12 | changde
# Processing Record 13 of Set 12 | ternate
# Processing Record 14 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 15 of Set 12 | ibotirama
# Processing Record 16 of Set 12 | nizwa
# Processing Record 17 of Set 12 | padang
# Processing Record 18 of Set 12 | tricase
# Processing Record 19 of Set 12 | owo
# Processing Record 20 of Set 12 | ust-ilimsk
# Processing Record 21 of Set 12 | canberra
# Processing Record 22 of Set 12 | saquena
# Processing Record 23 of Set 12 | najran
# Processing Record 24 of Set 12 | tura
# Processing Record 25 of Set 12 | acarau
# Processing Record 26 of Set 12 | bolu
# Processing Record 27 of Set 12 | kununurra
# Processing Record 28 of Set 12 | show low
# Processing Record 29 of Set 12 | oudtshoorn
# Processing Record 30 of Set 12 | biak
# Processing Record 31 of Set 12 | vangaindrano
# Processing Record 32 of Set 12 | obluche
# City not found. Skipping...
# Processing Record 33 of Set 12 | puerto escondido
# Processing Record 34 of Set 12 | takoradi
# Processing Record 35 of Set 12 | obo
# Processing Record 36 of Set 12 | savalou
# Processing Record 37 of Set 12 | cap malheureux
# Processing Record 38 of Set 12 | cayenne
# Processing Record 39 of Set 12 | cartagena
# Processing Record 40 of Set 12 | caxito
# Processing Record 41 of Set 12 | idrinskoye
# Processing Record 42 of Set 12 | antsohihy
# Processing Record 43 of Set 12 | lodja
# Processing Record 44 of Set 12 | fianga
# City not found. Skipping...
# Processing Record 45 of Set 12 | zephyrhills
# Processing Record 46 of Set 12 | rabo de peixe
# Processing Record 47 of Set 12 | revda
# Processing Record 48 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 49 of Set 12 | salinopolis
# Processing Record 50 of Set 12 | barra patuca
# Processing Record 1 of Set 13 | wanaka
# Processing Record 2 of Set 13 | shenzhen
# Processing Record 3 of Set 13 | lompoc
# Processing Record 4 of Set 13 | youhao
# Processing Record 5 of Set 13 | gambela
# Processing Record 6 of Set 13 | tanta
# Processing Record 7 of Set 13 | superior
# Processing Record 8 of Set 13 | guhagar
# Processing Record 9 of Set 13 | vila velha
# Processing Record 10 of Set 13 | kefalos
# Processing Record 11 of Set 13 | oyama
# Processing Record 12 of Set 13 | charters towers
# Processing Record 13 of Set 13 | bastia
# Processing Record 14 of Set 13 | pesca
# Processing Record 15 of Set 13 | maniitsoq
# Processing Record 16 of Set 13 | santa rosa
# Processing Record 17 of Set 13 | emba
# Processing Record 18 of Set 13 | san quintin
# Processing Record 19 of Set 13 | seoul
# Processing Record 20 of Set 13 | kloulklubed
# Processing Record 21 of Set 13 | saint-denis
# Processing Record 22 of Set 13 | manadhoo
# Processing Record 23 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 24 of Set 13 | chabahar
# Processing Record 25 of Set 13 | georgiyevskoye
# Processing Record 26 of Set 13 | valparaiso
# Processing Record 27 of Set 13 | salym
# Processing Record 28 of Set 13 | iranshahr
# Processing Record 29 of Set 13 | mantua
# Processing Record 30 of Set 13 | parras
# City not found. Skipping...
# Processing Record 31 of Set 13 | tomatlan
# Processing Record 32 of Set 13 | tabou
# Processing Record 33 of Set 13 | yelizovo
# Processing Record 34 of Set 13 | ewa beach
# Processing Record 35 of Set 13 | mamit
# Processing Record 36 of Set 13 | hammerfest
# Processing Record 37 of Set 13 | weligama
# Processing Record 38 of Set 13 | mandurah
# Processing Record 39 of Set 13 | berlevag
# Processing Record 40 of Set 13 | japura
# Processing Record 41 of Set 13 | chimoio
# Processing Record 42 of Set 13 | monrovia
# Processing Record 43 of Set 13 | kamenka
# Processing Record 44 of Set 13 | saint-augustin
# Processing Record 45 of Set 13 | masunga
# Processing Record 46 of Set 13 | san andres
# Processing Record 47 of Set 13 | wooster
# Processing Record 48 of Set 13 | ngunguru
# Processing Record 49 of Set 13 | dubenskiy
# City not found. Skipping...
# Processing Record 50 of Set 13 | talcahuano
# Processing Record 1 of Set 14 | ngara
# Processing Record 2 of Set 14 | panguna
# Processing Record 3 of Set 14 | litovko
# Processing Record 4 of Set 14 | iwanai
# Processing Record 5 of Set 14 | otane
# Processing Record 6 of Set 14 | viedma
# Processing Record 7 of Set 14 | malatya
# Processing Record 8 of Set 14 | luwuk
# Processing Record 9 of Set 14 | longlac
# City not found. Skipping...
# Processing Record 10 of Set 14 | kupang
# Processing Record 11 of Set 14 | sarangani
# Processing Record 12 of Set 14 | atambua
# Processing Record 13 of Set 14 | chancay
# Processing Record 14 of Set 14 | herrin
# Processing Record 15 of Set 14 | karratha
# Processing Record 16 of Set 14 | libertador general san martin
# Processing Record 17 of Set 14 | kencong
# Processing Record 18 of Set 14 | san miguel
# Processing Record 19 of Set 14 | progreso
# Processing Record 20 of Set 14 | kaeo
# Processing Record 21 of Set 14 | vostok
# Processing Record 22 of Set 14 | lumby
# Processing Record 23 of Set 14 | butere
# Processing Record 24 of Set 14 | port macquarie
# Processing Record 25 of Set 14 | azimur
# City not found. Skipping...
# Processing Record 26 of Set 14 | chlorakas
# Processing Record 27 of Set 14 | laramie
# Processing Record 28 of Set 14 | guadalajara
# Processing Record 29 of Set 14 | azuga
# Processing Record 30 of Set 14 | usinsk
# Processing Record 31 of Set 14 | mitchell
# Processing Record 32 of Set 14 | aswan
# Processing Record 33 of Set 14 | taunggyi
# Processing Record 34 of Set 14 | puerto madero
# Processing Record 35 of Set 14 | kawalu
# Processing Record 36 of Set 14 | bucerias
# Processing Record 37 of Set 14 | peno
# Processing Record 38 of Set 14 | czestochowa
# Processing Record 39 of Set 14 | gravdal
# Processing Record 40 of Set 14 | cururupu
# Processing Record 41 of Set 14 | port hardy
# Processing Record 42 of Set 14 | rocha
# Processing Record 43 of Set 14 | treinta y tres
# Processing Record 44 of Set 14 | bagan
# Processing Record 45 of Set 14 | magugu
# Processing Record 46 of Set 14 | marovoay
# Processing Record 47 of Set 14 | nantucket
# Processing Record 48 of Set 14 | abu samrah
# Processing Record 49 of Set 14 | payo
# Processing Record 50 of Set 14 | lamlash
# Processing Record 1 of Set 15 | santo tomas
# Processing Record 2 of Set 15 | pahrump
# Processing Record 3 of Set 15 | panama city
# Processing Record 4 of Set 15 | ambulu
# Processing Record 5 of Set 15 | bansang
# Processing Record 6 of Set 15 | carutapera
# Processing Record 7 of Set 15 | rawlins
# Processing Record 8 of Set 15 | celestun
# Processing Record 9 of Set 15 | portland
# Processing Record 10 of Set 15 | mayumba
# Processing Record 11 of Set 15 | la ronge
# Processing Record 12 of Set 15 | khonuu
# City not found. Skipping...
# Processing Record 13 of Set 15 | fort nelson
# Processing Record 14 of Set 15 | westport
# Processing Record 15 of Set 15 | calama
# Processing Record 16 of Set 15 | nyurba
# Processing Record 17 of Set 15 | bathurst
# Processing Record 18 of Set 15 | almaznyy
# Processing Record 19 of Set 15 | wainwright
# Processing Record 20 of Set 15 | uige
# Processing Record 21 of Set 15 | roebourne
# Processing Record 22 of Set 15 | simao
# Processing Record 23 of Set 15 | ugoofaaru
# Processing Record 24 of Set 15 | azalea park
# Processing Record 25 of Set 15 | yining
# Processing Record 26 of Set 15 | xining
# Processing Record 27 of Set 15 | tezu
# Processing Record 28 of Set 15 | timra
# Processing Record 29 of Set 15 | barceloneta
# Processing Record 30 of Set 15 | tevriz
# Processing Record 31 of Set 15 | carbonia
# Processing Record 32 of Set 15 | beira
# Processing Record 33 of Set 15 | owando
# Processing Record 34 of Set 15 | sulangan
# Processing Record 35 of Set 15 | la cruz
# Processing Record 36 of Set 15 | cukai
# Processing Record 37 of Set 15 | abu kamal
# Processing Record 38 of Set 15 | san ramon
# Processing Record 39 of Set 15 | shu
# Processing Record 40 of Set 15 | trelew
# Processing Record 41 of Set 15 | mosquera
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Nampa      US  43.5407 -116.5635     76.28        34           0
# 1  Nizhnevartovsk      RU  60.9344   76.5531     66.22        72           0
# 2    Bahia Blanca      AR -38.7196  -62.2724     48.02        76         100
# 3    Punta Arenas      CL -53.1500  -70.9167     30.31        74          20
# 4         Manggar      ID  -2.8833  108.2667     78.26        87         100
# 5  Guerrero Negro      MX  27.9769 -114.0611     73.31        54           0
# 6      Nanortalik      GL  60.1432  -45.2371     38.88        98         100
# 7           Kapaa      US  22.0752 -159.3190     84.18        76          75
# 8       Mount Isa      AU -20.7333  139.5000     67.77        49         100
# 9         Foligno      IT  42.9440   12.7011     68.13        49          34
#
#    Wind Speed Weather Description
# 0       10.36           clear sky
# 1        8.99           clear sky
# 2       10.54     overcast clouds
# 3       10.36          few clouds
# 4       16.55     overcast clouds
# 5       16.64           clear sky
# 6        9.89          light rain
# 7       12.66       broken clouds
# 8       10.36     overcast clouds
# 9        5.97    scattered clouds

# %%
len(city_data_df)
# Out:
# 680

# %%
pwd
# Out:
# '/Users/cameronchapa/Downloads/School Related/Bootcamp Stuff/Analysis Projects/Project 6 /Weather_Database'

# %%
city_data_df.to_csv(r'/Users/cameronchapa/Downloads/School Related/Bootcamp Stuff/Analysis Projects/Project 6 /Weather_Database/Weather_Database.csv')
